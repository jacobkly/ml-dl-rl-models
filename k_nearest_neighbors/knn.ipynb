# %%
# import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
# load the dataset from a CSV into a pandas DataFrame
df = pd.read_csv('hsbdemo.csv')

# split the dataset into input features and target variable for 70% training and 30% testing
X_train, X_test, y_train, y_test = train_test_split(df[['read', 'write', 'math', 'science']],
                                                    df['prog'], test_size=0.30)

# %%
res = [] # initilaze empty list to store accuracy results for different k values

# loop over odd k values 1 to 51 (smaller dataset) to find best k value for classifier
for k in range(1, 51, 2):
    classifier = KNeighborsClassifier(n_neighbors=k) # KNN classifier instance with k neighbors
    classifier.fit(X_train, y_train)  # train the classifier
    prediction = classifier.predict(X_test) # make prediction on test set
    accuracy = np.where(prediction==y_test, 1, 0).sum() / len(y_test) # calculate accuracy
    print(f'k = {k}   accuracy = {accuracy}')
    res.append([k, accuracy]) # store k and accuracy result

# convert res list to a DataFrame for plotting
res = pd.DataFrame(res, columns=['k', 'accuracy'])

# plot accuracy values against different k values
plt.plot(res.k, res.accuracy)
plt.title("Value of k and Corresponding Classification Accuracy")
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Accuracy")
plt.show()
# Out:
# k = 1   accuracy = 0.5833333333333334
# k = 3   accuracy = 0.6666666666666666
# k = 5   accuracy = 0.6333333333333333
# k = 7   accuracy = 0.65
# k = 9   accuracy = 0.65
# k = 11   accuracy = 0.65
# k = 13   accuracy = 0.6333333333333333
# k = 15   accuracy = 0.5833333333333334
# k = 17   accuracy = 0.5666666666666667
# k = 19   accuracy = 0.5833333333333334
# k = 21   accuracy = 0.6
# k = 23   accuracy = 0.5833333333333334
# k = 25   accuracy = 0.55
# k = 27   accuracy = 0.6
# k = 29   accuracy = 0.6166666666666667
# k = 31   accuracy = 0.65
# k = 33   accuracy = 0.6333333333333333
# k = 35   accuracy = 0.6333333333333333
# k = 37   accuracy = 0.6666666666666666
# k = 39   accuracy = 0.6666666666666666
# k = 41   accuracy = 0.6333333333333333
# k = 43   accuracy = 0.6666666666666666
# k = 45   accuracy = 0.6666666666666666
# k = 47   accuracy = 0.65
# k = 49   accuracy = 0.6333333333333333

# %%
# Results:
# After testing various parts of this KNN classifier model (e.g., 70-30 split vs. 80-20 split, 
# k values ranging from 1-51), the best average results and classifier accuracies came from 
# having k values with the ranges of 5-19. However, larger k values were also able to obtain 
# higher classification accuracy.
